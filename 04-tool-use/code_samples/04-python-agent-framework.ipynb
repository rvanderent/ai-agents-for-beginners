# %% [markdown]
# # 🛠️ Advanced Tool Use with GitHub Models (Python)
#
# ## 📋 Learning Objectives
#
# This notebook demonstrates advanced tool integration patterns using the Microsoft Agent Framework with GitHub Models. You'll learn how to create, manage, and orchestrate multiple tools to build sophisticated agent capabilities.
#
# **What You'll Master:**
# - 🔧 **Multi-Tool Architecture**: Building agents with multiple specialized tools
# - 🎯 **Tool Selection Logic**: How agents choose the right tool for each task
# - 📊 **Data Processing Tools**: Creating tools that handle different data types
# - 🔗 **Tool Composition**: Combining tools for complex workflows
#
# ## 🎯 Key Tool Patterns
#
# ### Tool Design Principles
# - **Single Responsibility**: Each tool has a clear, focused purpose
# - **Type Safety**: Strong typing for reliable tool execution
# - **Error Handling**: Graceful failure and recovery patterns
# - **Composability**: Tools that work well together
#
# ### Advanced Tool Features
# - **Context Awareness**: Tools that understand conversation context
# - **Data Validation**: Input sanitization and output validation
# - **Performance Optimization**: efficient tool execution patterns
# - **Extensibility**: Easy addition of new tool capabilities
#
# ## 🔧 Technical Architecture
#
# ### Core Components
# - **Microsoft Agent Framework**: Python implementation with advanced tool support
# - **GitHub Models Integration**: High-performance language model access
# - **Tool Registry System**: Organized management of agent capabilities
# - **Error Recovery Patterns**: Robust handling of tool execution failures
#
# ### Tool Integration Flow
# ```python
# User Request → Agent Analysis → Tool Selection → Tool Execution → Response Synthesis
# ```
#
# ## 🛠️ Tool Categories Demonstrated
#
# ### 1. **Data Generation Tools**
# - Random destination generator
# - Weather information provider
# - Travel cost calculator
# - Activity recommendation engine
#
# ### 2. **Processing Tools**
# - Text formatting and validation
# - Data transformation utilities
# - Content analysis functions
# - Response enhancement tools
#
# ### 3. **Integration Tools**
# - External API connectors
# - File system operations
# - Database query interfaces
# - Web scraping utilities
#
# ## ⚙️ Prerequisites & Setup
#
#
# **Required Dependencies:**
# ```bash
#
# pip install agent-framework-core -U
# ```
#
# **Environment Configuration (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Optional APIs:**
# - Weather service API key (for weather tools)
# - Currency conversion API access
# - Travel information service credentials
#
# ## 🎨 Design Patterns
#
# ### Tool Factory Pattern
# - Centralized tool creation and configuration
# - Consistent tool interface design
# - Easy tool registration and discovery
#
# ### Command Pattern
# - Encapsulated tool execution logic
# - Undo/redo functionality for complex operations
# - Audit logging for tool usage
#
# ### Observer Pattern
# - Tool execution monitoring
# - Performance metrics collection
# - Error reporting and alerting
#
# ## 🚀 Best Practices
#
# - **Tool Documentation**: Clear descriptions for agent understanding
# - **Input Validation**: Robust parameter checking and sanitization
# - **Output Formatting**: Consistent, parseable tool responses
# - **Error Messages**: Helpful error information for debugging
# - **Performance**: Optimized tool execution for responsiveness
#
# Ready to build agents with powerful tool capabilities? Let's create something amazing! ⚡

# %%
! pip install agent-framework-core -U
# Out:
# Requirement already satisfied: agent-framework-core in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (1.0.0b251223)
# Requirement already satisfied: typing-extensions in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from agent-framework-core) (4.15.0)
# Requirement already satisfied: pydantic<3,>=2 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from agent-framework-core) (2.11.10)
# Requirement already satisfied: pydantic-settings<3,>=2 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from agent-framework-core) (2.12.0)
# Requirement already satisfied: opentelemetry-api>=1.39.0 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from agent-framework-core) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.39.0 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from agent-framework-core) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from agent-framework-core) (0.4.13)
# Requirement already satisfied: openai>=1.99.0 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from agent-framework-core) (1.109.1)
# Requirement already satisfied: azure-identity<2,>=1 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from agent-framework-core) (1.25.1)
# Requirement already satisfied: mcp>=1.23 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from mcp[ws]>=1.23->agent-framework-core) (1.24.0)
# Requirement already satisfied: packaging>=24.1 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from agent-framework-core) (25.0)
# Requirement already satisfied: azure-core>=1.31.0 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.37.0)
# Requirement already satisfied: cryptography>=2.5 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from azure-identity<2,>=1->agent-framework-core) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from pydantic<3,>=2->agent-framework-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from pydantic<3,>=2->agent-framework-core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from pydantic<3,>=2->agent-framework-core) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from pydantic-settings<3,>=2->agent-framework-core) (1.2.1)
# Requirement already satisfied: requests>=2.21.0 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.0.0)
# Requirement already satisfied: pycparser in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.23)
# Requirement already satisfied: anyio>=4.5 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (4.12.0)
# Requirement already satisfied: httpx-sse>=0.4 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (4.25.1)
# Requirement already satisfied: pyjwt>=2.10.1 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (0.0.21)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (3.0.4)
# Requirement already satisfied: starlette>=0.27 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (0.50.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (0.38.0)
# Requirement already satisfied: idna>=2.8 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from anyio>=4.5->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (3.11)
# Requirement already satisfied: certifi in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from httpx>=0.27.1->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from httpx>=0.27.1->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (0.30.0)
# Requirement already satisfied: websockets>=15.0.1 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from mcp[ws]>=1.23->agent-framework-core) (15.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.6.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core) (0.12.0)
# Requirement already satisfied: sniffio in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openai>=1.99.0->agent-framework-core) (4.67.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from opentelemetry-api>=1.39.0->agent-framework-core) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.39.0->agent-framework-core) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from opentelemetry-sdk>=1.39.0->agent-framework-core) (0.60b1)
# Requirement already satisfied: click>=7.0 in /Users/robvanderent/Code/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from uvicorn>=0.31.1->mcp>=1.23->mcp[ws]>=1.23->agent-framework-core) (8.3.1)

# %%
# � Import core dependencies for Agent Framework and tool integration
# This sets up the essential libraries for building intelligent agents with tool capabilities

import asyncio
import os
import json

from dotenv import load_dotenv  # For loading environment variables securely
from random import randint

# These are the core components for building tool-enabled agents
from agent_framework import ChatAgent           # Main agent class
from agent_framework.openai import OpenAIChatClient  # OpenAI-compatible client

# %%
load_dotenv()
# Out:
# True

# %%
# 🔑 Environment variables verification
# Ensure all required GitHub Models credentials are properly configured
print("GITHUB_ENDPOINT:", os.environ.get("GITHUB_ENDPOINT"))
print("GITHUB_TOKEN:", "***" if os.environ.get("GITHUB_TOKEN") else "Not set")
print("GITHUB_MODEL_ID:", os.environ.get("GITHUB_MODEL_ID"))
# Out:
# GITHUB_ENDPOINT: https://models.github.ai/inference
# GITHUB_TOKEN: ***
# GITHUB_MODEL_ID: gpt-4o-mini

# %%
# 🧪 Test GitHub Models connectivity
openai_chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
# 🛠️ Define travel planning tools for agent integration
# These functions provide specific capabilities that the agent can invoke dynamically

def get_random_destination() -> str:
    """
    🎲 Random destination generator tool
    Returns a randomly selected travel destination from curated list
    Useful when customers need inspiration for their next vacation
    """
    destinations = [
        "Paris, France",
        "Tokyo, Japan", 
        "New York City, USA",
        "London, England",
        "Rome, Italy",
        "Sydney, Australia",
        "Dubai, UAE",
        "Barcelona, Spain",
        "Bangkok, Thailand",
        "Amsterdam, Netherlands",
        "Istanbul, Turkey",
        "Prague, Czech Republic",
        "Santorini, Greece",
        "Reykjavik, Iceland",
        "Marrakech, Morocco",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # 🎯 Return random selection from the curated destination list
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Initialize GitHub Models chat client for agent communication
# Creates the primary interface between the agent and the language model
openai_chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
# 🤖 Configure travel agent identity and behavioral instructions
# Define the agent's personality, capabilities, and operational guidelines

AGENT_NAME = "TravelAgent"

AGENT_INSTRUCTIONS = """You are a helpful AI Agent that can help plan vacations for customers at random destinations
"""

# %%
agent = ChatAgent(
        name = AGENT_NAME,
        chat_client=openai_chat_client,
        instructions=AGENT_INSTRUCTIONS,
        tools=[get_random_destination]
)

# %%
thread = agent.get_new_thread()

# %%
response1 = await agent.run("Plan me a day trip",thread= thread)

# %%
last_message = response1.messages[-1]
text_content = last_message.contents[0].text
print("Travel plan:")
print(text_content)
# Out:
# Travel plan:
# How about a day trip to the beautiful island of Santorini, Greece? Here's a suggested itinerary for your day:
#
# ### Morning:
# 1. **Breakfast**: Start your day with a traditional Greek breakfast at a local café. Try some yogurt with honey and fresh fruit, along with a strong Greek coffee.
#
# 2. **Explore Oia**: After breakfast, head to Oia, famous for its stunning white-washed buildings and blue-domed churches. Take a leisurely stroll through the charming streets, stopping for photos and enjoying the views.
#
# ### Midday:
# 3. **Visit a Winery**: Santorini is known for its unique wines, especially the Assyrtiko variety. Visit a local winery for a tour and tasting session that showcases the local viticulture.
#
# 4. **Lunch**: Enjoy a leisurely lunch at a seaside taverna. Order fresh seafood and local dishes while enjoying the view of the Aegean Sea.
#
# ### Afternoon:
# 5. **Relax at the Beach**: Spend some time at one of Santorini's unique beaches, such as Red Beach or Perissa Beach. Relax, swim, or simply soak in the sun.
#
# 6. **Ancient Akrotiri**: Visit the archaeological site of Akrotiri, which features the ruins of an ancient Minoan city preserved in volcanic ash.
#
# ### Evening:
# 7. **Sunset in Fira**: Head to the capital, Fira, to find a spot to watch the famous Santorini sunset. Many restaurants and cafes offer spectacular views.
#
# 8. **Dinner**: Finish your day with a dinner at a cliffside restaurant, enjoying local dishes and perhaps a glass of ouzo or wine while watching the sun dip below the horizon.
#
# ### Additional Tips:
# - Wear comfortable shoes for walking.
# - Consider renting a scooter or ATV to explore the island easily.
# - Bring a camera to capture the stunning scenery!
#
# Enjoy your day trip to Santorini!
